# %% [markdown]
# # TURTLE

# %% [markdown]
# ## 1. DERS --- Turtle Giriş

# %%
from turtle import Turtle, Screen


tosbaga = Turtle()

tosbaga.shape("turtle")
tosbaga.color("blue")
tosbaga.forward(100)

print(tosbaga)

my_screen = Screen()
print(my_screen.canvwidth)
print(my_screen.canvheight)
my_screen.exitonclick() # basana kadar çıkma
# Out:
# ...
# 400
# 300

# %%
from turtle import Turtle, Screen

tosbaga = Turtle()
tosbaga.forward(100)
tosbaga.right(90)
tosbaga.forward(100)
tosbaga.right(90)
tosbaga.forward(100)
tosbaga.left(45)
tosbaga.forward(100)
tosbaga.right(90)
tosbaga.forward(100)
tosbaga.right(90)
tosbaga.forward(100)
tosbaga.forward(70)
tosbaga.right(90)
tosbaga.forward(30)

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen

tosbaga = Turtle()

for i in range(4):
    tosbaga.forward(100)
    tosbaga.right(90)
    

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen

tosbaga = Turtle()

kenar_sayisi = 11
for i in range(kenar_sayisi):
    aci = 360 / kenar_sayisi
    tosbaga.forward(50)
    tosbaga.right(aci)
    
    

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen

tosbaga = Turtle()

def sekilCiz(kenar_sayisi):
    aci = 360 / kenar_sayisi
    
    for i in range(kenar_sayisi):
        kenar_sayisi = 11
        tosbaga.forward(50)
        tosbaga.right(aci)

for x in range(3,12):
    sekilCiz(x)
    

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen
import random

tosbaga = Turtle()

renkler = ["AliceBlue","blue4","DarkOrchid4","coral2","aquamarine4","BlueViolet","beige","black"]

def sekilCiz(kenar_sayisi):
    aci = 360 / kenar_sayisi
    
    for i in range(kenar_sayisi):
        kenar_sayisi = 11
        tosbaga.forward(50)
        tosbaga.right(aci)

for x in range(3,12):
    tosbaga.color(random.choice(renkler))
    sekilCiz(x)
    

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %% [markdown]
# ## 2. DERS --- Turtle temelleri 2

# %%
from turtle import Turtle, Screen
from random import choice, randint
import turtle

tosbaga = Turtle()
tosbaga.pensize(10)
tosbaga.speed("normal")

turtle.colormode(255)

#renkler = ["AliceBlue","blue4","DarkOrchid4","coral2","aquamarine4","BlueViolet","beige","black"]

def renk_uret():
    r = randint(0,255)
    g = randint(0,255)
    b = randint(0,255)
    random_color = (r,g,b)
    return random_color
    
yonler = [0, 90, 180, 270]

for i in range(45):
    tosbaga.color(renk_uret())
    tosbaga.forward(50)
    tosbaga.setheading(choice(yonler))
    

my_screen = Screen()
my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen
from random import choice, randint
import turtle

tosbaga = Turtle()
my_screen = Screen()

tosbaga.pensize(3)
tosbaga.speed("normal")

def ileri():
    tosbaga.forward(33)

def geri():
    tosbaga.backward(33)

def saga_don():
    tosbaga.setheading(tosbaga.heading()-10)

def sola_don():
    tosbaga.setheading(tosbaga.heading()+10)

def temizle():
    tosbaga.clear()
    tosbaga.penup()
    tosbaga.home()
    tosbaga.pendown()
    


my_screen.listen()
my_screen.onkey(fun=ileri, key="w")
my_screen.onkey(fun=geri, key="s")
my_screen.onkey(fun=saga_don, key="d")
my_screen.onkey(fun=sola_don, key="a")
my_screen.onkey(temizle, "t")


my_screen.exitonclick() # basana kadar çıkma

# %% [raw]
# koordinat sistemi anlat

# %%
from turtle import Turtle, Screen
from random import choice, randint
import turtle

tosbaga = Turtle()
my_screen = Screen()
my_screen.setup(width=1000, height=600)
tosbaga.goto(300,300)



my_screen.exitonclick() # basana kadar çıkma

# %% [markdown]
# ## 3. DERS ---- Kaplumbağalar yarışıyor1

# %%
from turtle import Turtle, Screen


tosbaga = Turtle()
my_screen = Screen()
my_screen.setup(width=1000, height=600)
soru = my_screen.textinput(title="Tahminini yap!!!", prompt="Sence hangi renk kazanacak?")
renkler = {"red", "green", "blue", "yellow", "purple"}
tosbaga.setheading(90)
tosbaga.penup()
tosbaga.goto(0,-250)



my_screen.exitonclick() # basana kadar çıkma

# %%
from turtle import Turtle, Screen



my_screen = Screen()
my_screen.setup(width=1000, height=600)
soru = my_screen.textinput(title="Tahminini yap!!!", prompt="Sence hangi renk kazanacak?")
renkler = ["red", "blue", "black", "yellow", "green", "purple"]

x_pozisyon = [-300,-200,-100,0,100,200,300]

for t in range(0,6):
    tosbaga = Turtle(shape="turtle")
    tosbaga.color(renkler[t])
    tosbaga.setheading(90)
    tosbaga.penup()
    tosbaga.goto(x_pozisyon[t],-250)





my_screen.exitonclick() # basana kadar çıkma

# %% [markdown]
# ## 4. DERS ---- Kaplumbağalar yarışıyor2

# %%
from turtle import Turtle, Screen
import random


my_screen = Screen()
my_screen.setup(width=1000, height=600)
soru = my_screen.textinput(title="Tahminini yap!!!", prompt="Sence hangi renk kazanacak?")
renkler = ["red", "blue", "black", "yellow", "green", "purple"]

x_pozisyon = [-300,-200,-100,0,100,200,300]
tosbagalar = []

for t in range(0,6):
    tosbaga = Turtle(shape="turtle")
    tosbaga.color(renkler[t])
    tosbaga.setheading(90)
    tosbaga.penup()
    tosbaga.goto(x_pozisyon[t],-250)
    tosbagalar.append(tosbaga)

yaris = False
if soru:
    yaris = True
    

while yaris:
    for tosbaga in tosbagalar:
        hiz = random.randint(0,10)
        tosbaga.forward(hiz)
        
        
    
    
my_screen.exitonclick() # basana kadar çıkma
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[1], line 18
#      16     tosbaga.setheading(90)
#      17     tosbaga.penup()
# ---> 18     tosbaga.goto(x_pozisyon[t],-250)
#      19     tosbagalar.append(tosbaga)
#      21 yaris = False
#
# File ~\anaconda3\Lib\turtle.py:1777, in TNavigator.goto(self, x, y)
#    1775     self._goto(Vec2D(*x))
#    1776 else:
# -> 1777     self._goto(Vec2D(x, y))
#
# File ~\anaconda3\Lib\turtle.py:3196, in RawTurtle._goto(self, end)
#    3192     if self._drawing:
#    3193         screen._drawline(self.drawingLineItem,
#    3194                          (start, self._position),
#    3195                          self._pencolor, self._pensize, top)
# -> 3196     self._update()
#    3197 if self._drawing:
#    3198     screen._drawline(self.drawingLineItem, ((0, 0), (0, 0)),
# ...

# %%
from turtle import Turtle, Screen
import random


my_screen = Screen()
my_screen.setup(width=1000, height=600)
soru = my_screen.textinput(title="Tahminini yap!!!", prompt="Sence hangi renk kazanacak?")
renkler = ["red", "blue", "black", "yellow", "green", "purple"]

x_pozisyon = [-300,-200,-100,0,100,200,300]
tosbagalar = []


for t in range(0,6):
    tosbaga = Turtle(shape="turtle")
    tosbaga.color(renkler[t])
    tosbaga.setheading(90)
    tosbaga.penup()
    tosbaga.goto(x_pozisyon[t],-250)
    tosbagalar.append(tosbaga)

yaris = False
if soru:
    yaris = True
    

while yaris:
    for tosbaga in tosbagalar:
        if tosbaga.ycor() > 250:
            yaris = False
            kazanan = tosbaga.pencolor()
            if kazanan == soru:
                print("kazandiniz")
            else:
                print("kaybettiniz")
            
        hiz = random.randint(0,10)
        tosbaga.forward(hiz)
        
        
    
    
my_screen.exitonclick() # basana kadar çıkma
# Out:
# kaybettiniz
# kaybettiniz

# %%
from turtle import Turtle, Screen
import random


my_screen = Screen()
my_screen.setup(width=1000, height=600)
soru = my_screen.textinput(title="Tahminini yap!!!", prompt="Sence hangi renk kazanacak?")
renkler = ["red", "blue", "black", "yellow", "green", "purple"]

x_pozisyon = [-300,-200,-100,0,100,200,300]
tosbagalar = []

def bitis_cizgisi():
    cizgi = Turtle()
    cizgi.hideturtle()
    cizgi.speed("fastest")
    cizgi.pensize(10)
    
    cizgi.penup()
    cizgi.goto(-500,250)
    cizgi.pendown()
    
    cizgi.forward(1000)
    

for t in range(0,6):
    tosbaga = Turtle(shape="turtle")
    tosbaga.color(renkler[t])
    tosbaga.setheading(90)
    tosbaga.penup()
    tosbaga.goto(x_pozisyon[t],-250)
    tosbagalar.append(tosbaga)

yaris = False
if soru:
    yaris = True
    
bitis_cizgisi()

while yaris:
    for tosbaga in tosbagalar:
        if tosbaga.ycor() > 250:
            yaris = False
            kazanan = tosbaga.pencolor()
            if kazanan == soru:
                print("kazandınız")
            else:
                print("kaybettiniz")
            
        hiz = random.randint(0,10)
        tosbaga.forward(hiz)
        
        
    
    
my_screen.exitonclick() # basana kadar çıkma
# Out:
# kaybettiniz

# %% [markdown]
# ## 5.  DERS ---- Yılan oyunu1

# %%
from turtle import Turtle, Screen
import random

sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("lightblue")
sc.title("YILAN OYUNU")

pozisyonlar = [(0,0),(-20,0),(-40,0)]
parcalar = []

for pozisyon in pozisyonlar:
    body = Turtle(shape="square")
    body.color("white")
    #body.penup()
    body.goto(pozisyon)
    parcalar.append(body)

oyun = True
while oyun:
    for parca in parcalar:
        parca.forward(20)
        


"""
body = Turtle(shape="square")
body.color("white")

body1 = Turtle(shape="square")
body1.color("white")
body1.goto(-20,0)

body2 = Turtle(shape="square")
body2.color("white")
body2.goto(20,0)
"""


sc.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 22
#      20 while oyun:
#      21     for parca in parcalar:
# ---> 22         parca.forward(20)
#      26 """
#      27 body = Turtle(shape="square")
#      28 body.color("white")
#    (...)
#      36 body2.goto(20,0)
#      37 """
#      40 sc.exitonclick()
#
# File ~\anaconda3\Lib\turtle.py:1638, in TNavigator.forward(self, distance)
#    1617 def forward(self, distance):
#    1618     """Move the turtle forward by the specified distance.
#    1619
#    1620     Aliases: forward | fd
#    (...)
#    1636     (-50.00,0.00)
#    1637     """
# -> 1638     self._go(distance)
#
# File ~\anaconda3\Lib\turtle.py:1606, in TNavigator._go(self, distance)
#    1604 """move turtle forward by specified distance"""
#    1605 ende = self._position + self._orient * distance
# -> 1606 self._goto(ende)
#
# ...

# %%
from turtle import Turtle, Screen


sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("lightblue")
sc.title("YILAN OYUNU")
sc.tracer(0) # body ler arasındaki aralıları kapatır

pozisyonlar = [(0,0),(-20,0),(-40,0)]
parcalar = []

for pozisyon in pozisyonlar:
    body = Turtle(shape="square")
    body.color("white")
    body.penup()
    body.goto(pozisyon)
    parcalar.append(body)


oyun = True
while oyun:
    sc.update() # ekranda guncelleme ve birlikte hareket etmeyi saglar
    for parca in parcalar:
        parca.forward(20)
        



sc.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 25
#      23     sc.update() # ekranda guncelleme ve birlikte hareket etmeyi saglar
#      24     for parca in parcalar:
# ---> 25         parca.forward(20)
#      30 sc.exitonclick()
#
# File ~\anaconda3\Lib\turtle.py:1638, in TNavigator.forward(self, distance)
#    1617 def forward(self, distance):
#    1618     """Move the turtle forward by the specified distance.
#    1619
#    1620     Aliases: forward | fd
#    (...)
#    1636     (-50.00,0.00)
#    1637     """
# -> 1638     self._go(distance)
#
# File ~\anaconda3\Lib\turtle.py:1606, in TNavigator._go(self, distance)
#    1604 """move turtle forward by specified distance"""
#    1605 ende = self._position + self._orient * distance
# -> 1606 self._goto(ende)
#
# File ~\anaconda3\Lib\turtle.py:3175, in RawTurtle._goto(self, end)
# ...

# %%
from turtle import Turtle, Screen
import time 

sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("lightblue")
sc.title("YILAN OYUNU")
sc.tracer(0) # body ler arasındaki aralıları kapatır

pozisyonlar = [(0,0),(-20,0),(-40,0)]
parcalar = []

for pozisyon in pozisyonlar:
    body = Turtle(shape="square")
    body.color("white")
    body.penup()
    body.goto(pozisyon)
    parcalar.append(body)


oyun = True
while oyun:
    sc.update() # ekranda guncelleme ve birlikte hareket etmeyi saglar
    time.sleep(0.1)
    for parca in parcalar:
        parca.forward(20)
        


sc.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 26
#      24     time.sleep(0.1)
#      25     for parca in parcalar:
# ---> 26         parca.forward(20)
#      30 sc.exitonclick()
#
# File ~\anaconda3\Lib\turtle.py:1638, in TNavigator.forward(self, distance)
#    1617 def forward(self, distance):
#    1618     """Move the turtle forward by the specified distance.
#    1619
#    1620     Aliases: forward | fd
#    (...)
#    1636     (-50.00,0.00)
#    1637     """
# -> 1638     self._go(distance)
#
# File ~\anaconda3\Lib\turtle.py:1606, in TNavigator._go(self, distance)
#    1604 """move turtle forward by specified distance"""
#    1605 ende = self._position + self._orient * distance
# -> 1606 self._goto(ende)
#
# File ~\anaconda3\Lib\turtle.py:3175, in RawTurtle._goto(self, end)
#    3167 go_modes = ( self._drawing,
#    3168              self._pencolor,
# ...

# %%
from turtle import Turtle, Screen
import time 

sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("lightblue")
sc.title("YILAN OYUNU")
sc.tracer(0) # body ler arasındaki aralıları kapatır

pozisyonlar = [(0,0),(-20,0),(-40,0)]
parcalar = []

for pozisyon in pozisyonlar:
    body = Turtle(shape="square")
    body.color("white")
    body.penup()
    body.goto(pozisyon)
    parcalar.append(body)


oyun = True
while oyun:
    sc.update() # ekranda guncelleme ve birlikte hareket etmeyi saglar
    time.sleep(0.1)
    
    """
    for parca in parcalar:
        parca.forward(20)
    """   
    # dönüşleri ayarlama, birbiri üzerine binmemeyi ayarlama
    for i in range(len(parcalar)-1,0,-1):
        x = parcalar[i-1].xcor()
        y = parcalar[i-1].ycor()
        parcalar[i].goto(x,y)
    parcalar[0].forward(20)
    parcalar[0].left(90)

sc.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 33
#      31     x = parcalar[i-1].xcor()
#      32     y = parcalar[i-1].ycor()
# ---> 33     parcalar[i].goto(x,y)
#      34 parcalar[0].forward(20)
#      35 parcalar[0].left(90)
#
# File ~\anaconda3\Lib\turtle.py:1777, in TNavigator.goto(self, x, y)
#    1775     self._goto(Vec2D(*x))
#    1776 else:
# -> 1777     self._goto(Vec2D(x, y))
#
# File ~\anaconda3\Lib\turtle.py:3175, in RawTurtle._goto(self, end)
#    3167 go_modes = ( self._drawing,
#    3168              self._pencolor,
#    3169              self._pensize,
#    3170              isinstance(self._fillpath, list))
#    3171 screen = self.screen
#    3172 undo_entry = ("go", self._position, end, go_modes,
#    3173               (self.currentLineItem,
#    3174               self.currentLine[:],
# ...

# %%
from turtle import Turtle, Screen
import random
import time

sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("purple")
sc.title("YILAN OYUNU")
sc.tracer(0)

oyun = True
while oyun:
    sc.update()
    time.sleep(0.1)



sc.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from turtle import Turtle, Screen
#       2 import time
# ----> 3 from yilan import Yilan
#       5 sc = Screen()
#       6 sc.setup = (800, 800)
#
# File ~\PycharmProjects\bilisimschool\oyun_kodlama\Turtle\yilan.py:51
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "6b14c308",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from turtle import Turtle, Screen\n",
#      11     "\n",
#      12     "pozisyonlar = [(0,0),(-20,0),(-40,0)]\n",
#      13     "\n",
#      14     "class Yilan:\n",
#      15     "    def __init__(self):\n",
#      16     "        self.parcalar = []\n",
#      17     "        self.body_olustur()\n",
# ...

# %% [markdown]
# ## 6. DERS--- YILAN OYUNU 2

# %%
from turtle import Turtle, Screen
import time
from yilan_deneme import Yilan
from yem_deneme import Yem
from skor_tablosu import SkorTablosu
sc = Screen()
sc.setup = (800, 800)
sc.bgcolor("lightblue")
sc.title("YILAN OYUNU")
sc.tracer(0)  # body ler arasındaki aralıları kapatır

yilan = Yilan()
yem = Yem()
skor_tablosu = SkorTablosu()

sc.listen()
sc.onkey(yilan.yukari, "Up")
sc.onkey(yilan.asagi, "Down")
sc.onkey(yilan.saga, "Right")
sc.onkey(yilan.sola, "Left")

oyun = True
while oyun:
    sc.update()  # ekranda guncelleme ve birlikte hareket etmeyi saglar
    time.sleep(0.1)
    yilan.hareket_et()

    if yilan.bas.distance(yem) < 15:
        yem.yenile()
        yilan.buyut()
        skor_tablosu.skor_arttir()

    if yilan.bas.xcor() > 390 or yilan.bas.xcor() < -390 or yilan.bas.ycor() > 390 or yilan.bas.ycor() < -390:
        oyun = False
        skor_tablosu.oyun_bitti()

    for parca in yilan.parcalar[1:]: # kendine değdiğinde oyunu bitir
        if yilan.bas.distance(parca) < 10:
            oyun = False
            skor_tablosu.oyun_bitti()


sc.exitonclick()

# %% [markdown]
# ## 7. DERS

# %% [raw]
# 1. Git Nedir?
#
# Açıklama:
# Git, yazılım geliştirme sürecinde kullanılan bir versiyon kontrol sistemidir. Bu sistem, bir proje üzerinde yapılan değişiklikleri kaydeder ve projede kimlerin ne zaman, ne tür değişiklikler yaptığını takip eder.
#
# Örnek:
# Diyelim ki bir hikaye yazıyorsunuz. Git, hikayenizin her versiyonunu saklar, böylece geri dönüp eski versiyonlara bakabilir veya hataları düzeltebilirsiniz.
#
# 2. GitHub Nedir?
#
# Açıklama:
# GitHub, projelerinizi internet üzerinde saklayabileceğiniz ve paylaşabileceğiniz bir platformdur. GitHub, Git'i kullanarak projelerinizi yönetmenize yardımcı olur. Ayrıca, diğer kullanıcılarla işbirliği yapmayı da kolaylaştırır.
#
# Örnek:
# GitHub, arkadaşlarınızla birlikte bir proje üzerinde çalışmanızı sağlar. Herkes projeye katkıda bulunabilir ve değişiklikler Git tarafından takip edilir.
#
# 3. GitHub Kullanımı - 1: Hesap Oluşturma
# Amaç: Öğrenciler, GitHub'da nasıl hesap oluşturacaklarını öğrenecekler.
#
# Adımlar:
#
# GitHub web sitesine (github.com) gidin.
# "Sign up" düğmesine tıklayın.
# Kullanıcı adı, e-posta adresi ve şifre gibi bilgileri girerek hesap oluşturun.
# 4. GitHub Kullanımı - 2: Depo (Repository) Oluşturma
# Amaç: Öğrenciler, GitHub'da nasıl depo oluşturacaklarını öğrenecekler.
#
# Adımlar:
#
# GitHub hesabınıza giriş yapın.
# Sağ üst köşedeki "+" işaretine tıklayın ve "New repository" seçeneğini seçin.
# Depo adı ve açıklama gibi bilgileri girin, ardından "Create repository" düğmesine tıklayın.
# 5. GitHub Kullanımı - 3: Proje Yükleme ve Yönetme
# Amaç: Öğrenciler, projelerini GitHub deposuna nasıl yükleyeceklerini ve yöneteceklerini öğrenecekler.
#
# Adımlar:
#
# Bilgisayarınızda bir proje klasörü oluşturun.
# Bu klasöre terminal veya komut satırı kullanarak gidin.
# git init komutunu yazarak git deposu başlatın.
# git add . komutunu yazarak tüm dosyaları ekleyin.
# git commit -m "İlk commit" komutunu yazarak değişiklikleri kaydedin.
# GitHub'da oluşturduğunuz depoya gidin ve "Quick setup" bölümündeki URL'yi kopyalayın.
# git remote add origin [URL] komutunu kullanarak uzak depoyu ekleyin.
# git push -u origin master komutunu kullanarak projeyi yükleyin.
# 6. PyCharm GitHub Kullanımı - 1: PyCharm ile GitHub'a Bağlanma
# Amaç: Öğrenciler, PyCharm IDE'si ile GitHub'a nasıl bağlanacaklarını öğrenecekler.
#
# Adımlar:
#
# PyCharm'ı açın ve "VCS" menüsüne gidin.
# "Checkout from Version Control" seçeneğini seçin ve "Git"i seçin.
# GitHub depo URL'sini girin ve projeyi indirin.
# 7. PyCharm GitHub Kullanımı - 2: PyCharm ile Değişiklik Yapma ve Yükleme
# Amaç: Öğrenciler, PyCharm'da yaptıkları değişiklikleri GitHub'a nasıl yükleyeceklerini öğrenecekler.
#
# Adımlar:
#
# PyCharm'da projede değişiklik yapın.
# "VCS" menüsüne gidin ve "Commit" seçeneğini seçin.
# Değişiklikleri açıklama ile birlikte kaydedin.
# "Push" seçeneğini seçerek değişiklikleri GitHub'a yükleyin.
# 8. .gitignore Dosyası
# Amaç: Öğrenciler, .gitignore dosyasının ne olduğunu ve nasıl kullanıldığını öğrenecekler.
#
# Açıklama:
# .gitignore dosyası, Git'in takip etmemesi gereken dosyaları belirlemek için kullanılır. Bu dosya, proje klasörünüzde bulunur ve içerisine hangi dosya veya klasörlerin Git tarafından takip edilmemesi gerektiğini yazarız.
#
# Örnek:
# """
# # .gitignore örneği
# __pycache__/
# *.pyc
# .env
# """
# Bu dosyada, __pycache__ klasörünü, .pyc uzantılı dosyaları ve .env dosyasını git tarafından takip edilmeyecek şekilde belirledik.

# %% [raw]
# git config --global user.email "admcns45@gmail.com"
#
# git config --global user.name "Adem"
#
# #cd C:\Users\admcn\my_project
#
#
# git init
#
# git add .
#
# git commit -m "ilk commit"
#
# git remote add origin https://github.com/edmbkrc/oyun_kodlama1
#
# git push -u origin master

# %%
import turtle
import time
import random

delay = 0.1
score = 0
high_score = 0

# Set up the screen
wn = turtle.Screen()
wn.title("Snake Game")
wn.bgcolor("darkblue")
wn.setup(width=600, height=600)
wn.tracer(0) # Turns off the screen updates

# Snake head
head = turtle.Turtle()
head.speed(0)
head.shape("square")
head.color("white")
head.penup()
head.goto(0,0)
head.direction = "stop"

# Snake food
food = turtle.Turtle()
food.speed(0)
food.shape("circle")
food.color("red")
food.penup()
food.goto(0,100)

segments = []

# Functions
def go_up():
    if head.direction != "down":
        head.direction = "up"

def go_down():
    if head.direction != "up":
        head.direction = "down"

def go_left():
    if head.direction != "right":
        head.direction = "left"

def go_right():
    if head.direction != "left":
        head.direction = "right"

def move():
    if head.direction == "up":
        y = head.ycor()
        head.sety(y + 20)

    if head.direction == "down":
        y = head.ycor()
        head.sety(y - 20)

    if head.direction == "left":
        x = head.xcor()
        head.setx(x - 20)

    if head.direction == "right":
        x = head.xcor()
        head.setx(x + 20)

# Keyboard bindings
wn.listen()
wn.onkeypress(go_up, "w")
wn.onkeypress(go_down, "s")
wn.onkeypress(go_left, "a")
wn.onkeypress(go_right, "d")

# Main game loop
while True:
    wn.update()

    # Check for a collision with the border
    if head.xcor()>290 or head.xcor()<-290 or head.ycor()>290 or head.ycor()<-290:
        time.sleep(1)
        head.goto(0,0)
        head.direction = "stop"
        
        # Hide the segments
        for segment in segments:
            segment.goto(1000, 1000)
        
        # Clear the segments list
        segments.clear()
        score = 0

    # Check for a collision with the food
    if head.distance(food) < 20:
        # Move the food to a random spot
        x = random.randint(-290, 290)
        y = random.randint(-290, 290)
        food.goto(x,y)

        # Add a segment
        new_segment = turtle.Turtle()
        new_segment.speed(0)
        new_segment.shape("square")
        new_segment.color("grey")
        new_segment.penup()
        segments.append(new_segment)

        # Increase the score
        score += 10

        if score > high_score:
            high_score = score

    # Move the end segments first in reverse order
    for index in range(len(segments)-1, 0, -1):
        x = segments[index-1].xcor()
        y = segments[index-1].ycor()
        segments[index].goto(x, y)

    # Move segment 0 to where the head is
    if len(segments) > 0:
        x = head.xcor()
        y = head.ycor()
        segments[0].goto(x, y)

    move()    

    # Check for head collision with the body segments
    for segment in segments:
        if segment.distance(head) < 20:
            time.sleep(1)
            head.goto(0,0)
            head.direction = "stop"
            
            # Hide the segments
            for segment in segments:
                segment.goto(1000, 1000)

            segments.clear()
            score = 0

    time.sleep(delay)

wn.mainloop()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 78
#      76 # Main game loop
#      77 while True:
# ---> 78     wn.update()
#      80     # Check for a collision with the border
#      81     if head.xcor()>290 or head.xcor()<-290 or head.ycor()>290 or head.ycor()<-290:
#
# File ~\anaconda3\Lib\turtle.py:1304, in TurtleScreen.update(self)
#    1302 self._tracing = True
#    1303 for t in self.turtles():
# -> 1304     t._update_data()
#    1305     t._drawturtle()
#    1306 self._tracing = tracing
#
# File ~\anaconda3\Lib\turtle.py:2647, in RawTurtle._update_data(self)
#    2646 def _update_data(self):
# -> 2647     self.screen._incrementudc()
#    2648     if self.screen._updatecounter != 0:
#    2649         return
#
# File ~\anaconda3\Lib\turtle.py:1293, in TurtleScreen._incrementudc(self)
#    1291 if not TurtleScreen._RUNNING:
# ...
